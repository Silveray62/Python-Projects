# %% [markdown]
# ### ***ydata-profiling checkpoint 1***
#
# Objective
# In this checkpoint, we are going to work on 'Education Attainment And Enrolment Around The World' dataset, provided by the World bank group.
#
# Dataset description : The dataset was derived from the original copy, which was published on the world bank website. The primary purpose of this database is to document and analyse patterns of educational attainment rates in different country around the world.
# ###

# %% [markdown]
# ***Instructions***
# - Step 1: Data exploration with Pandas
# - Download the provided dataset
# - Use pandas to read the file into a pandas Dataframe.
# - Display general information about the dataset.
# - Run descriptive analysis on the dataset using the 'describe' function.
# - Step 2: Data exploration with ydata-profiling
# - Use ydata-profiling to generate a report of the provided dataset.
# - Look for missing values in the dataset. You can use the report generated by ydata to identify missing values.
# - Examine the correlations between different columns in the dataset. You can use the report generated by ydata to identify correlations.
# Identify any other interesting patterns or insights in the dataset that you can discover through the ydata-profiling report.
# - Step 3: Summary
# - Write a summary of your findings based on the ydata-profiling report. Be sure to include any interesting patterns or insights you discovered in the dataset.

# %%
import pandas as pd
import seaborn as sns
from ydata_profiling import ProfileReport

# %%
df = pd.read_csv(r"C:\Users\DELL\Downloads\EDUCATION_ATTAINMENT.csv")

# %%
data_profiling = df.head(10)
data_profiling
# Out:
#    Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# 0                0.669091                0.667214                0.651812
# 1                0.485879                0.480171                0.465510
# 2                0.516431                0.514233                0.502269
# 3                0.914294                0.903528                0.871690
# 4                0.876990                0.841497                0.762864
# 5                0.889589                0.852069                0.771968
# 6                0.803733                0.746789                0.631720
# 7                0.981062                0.981062                0.980476
# 8                0.991079                0.985556                0.981743
# 9                0.992481                0.990077                0.984427
#
#    Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# 0                0.460899                0.458749                0.446925
# ...

# %%
#Display general information about the dataset.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ages[15-49]_All_grade1     626 non-null    float64
#  1   Ages[15-49]_All_grade2     626 non-null    float64
#  2   Ages[15-49]_All_grade3     626 non-null    float64
#  3   Ages[20-29]_All_grade1     626 non-null    float64
#  4   Ages[20-29]_All_grade2     626 non-null    float64
#  5   Ages[20-29]_All_grade3     626 non-null    float64
#  6   Ages[30-39]_All_grade1     625 non-null    float64
#  7   Ages[30-39]_All_grade2     625 non-null    float64
#  8   Ages[30-39]_All_grade3     625 non-null    float64
#  9   Ages[40-49]_All_grade1     625 non-null    float64
#  10  Ages[40-49]_All_grade2     625 non-null    float64
#  11  Ages[40-49]_All_grade3     625 non-null    float64
#  12  Ages[15-49]_Male_grade1    626 non-null    float64
# ...

# %%
#Run descriptive analysis on the dataset using the 'describe' function.
df.describe()
# Out:
#        Ages[15-49]_All_grade1  Ages[15-49]_All_grade2  Ages[15-49]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.873886                0.861490                0.837509
# std                  0.162624                0.166895                0.176555
# min                  0.251917                0.244071                0.233274
# 25%                  0.831791                0.803131                0.757465
# 50%                  0.948926                0.935167                0.909587
# 75%                  0.984447                0.980112                0.971166
# max                  1.000000                1.000000                1.000000
#
#        Ages[20-29]_All_grade1  Ages[20-29]_All_grade2  Ages[20-29]_All_grade3  \
# count              626.000000              626.000000              626.000000
# mean                 0.823849                0.812738                0.789965
# ...

# %%
profile = ProfileReport(df, title='Education Attainment Profile', explorative=True)
profile.to_file("Education_Attainment_profile_report.html")
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# C:\Users\DELL\anaconda3\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
# C:\Users\DELL\anaconda3\Lib\site-packages\ydata_profiling\model\missing.py:78: UserWarning: There was an attempt to generate the Heatmap missing values diagrams, but this failed.
# To hide this warning, disable the calculation
# (using `df.profile_report(missing_diagrams={"Heatmap": False}`)
# If this is problematic for your use case, please report this as an issue:
# https://github.com/ydataai/ydata-profiling/issues
# (include the error message: 'could not convert string to float: '--'')
#   warnings.warn(
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
#Look for missing values in the dataset. You can use the report generated by ydata to identify missing values.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 626 entries, 0 to 625
# Data columns (total 38 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Ages[15-49]_All_grade1     626 non-null    float64
#  1   Ages[15-49]_All_grade2     626 non-null    float64
#  2   Ages[15-49]_All_grade3     626 non-null    float64
#  3   Ages[20-29]_All_grade1     626 non-null    float64
#  4   Ages[20-29]_All_grade2     626 non-null    float64
#  5   Ages[20-29]_All_grade3     626 non-null    float64
#  6   Ages[30-39]_All_grade1     625 non-null    float64
#  7   Ages[30-39]_All_grade2     625 non-null    float64
#  8   Ages[30-39]_All_grade3     625 non-null    float64
#  9   Ages[40-49]_All_grade1     625 non-null    float64
#  10  Ages[40-49]_All_grade2     625 non-null    float64
#  11  Ages[40-49]_All_grade3     625 non-null    float64
#  12  Ages[15-49]_Male_grade1    626 non-null    float64
# ...

# %%
missing_values = print(df.isnull().sum())
missing_values
# Out:
# Ages[15-49]_All_grade1       0
# Ages[15-49]_All_grade2       0
# Ages[15-49]_All_grade3       0
# Ages[20-29]_All_grade1       0
# Ages[20-29]_All_grade2       0
# Ages[20-29]_All_grade3       0
# Ages[30-39]_All_grade1       1
# Ages[30-39]_All_grade2       1
# Ages[30-39]_All_grade3       1
# Ages[40-49]_All_grade1       1
# Ages[40-49]_All_grade2       1
# Ages[40-49]_All_grade3       1
# Ages[15-49]_Male_grade1      0
# Ages[15-49]_Male_grade2      0
# Ages[15-49]_Male_grade3      0
# Ages[20-29]_Male_grade1      0
# Ages[20-29]_Male_grade2      0
# Ages[20-29]_Male_grade3      0
# Ages[30-39]_Male_grade1      1
# Ages[30-39]_Male_grade2      1
# Ages[30-39]_Male_grade3      1
# Ages[40-49]_Male_grade1      1
# Ages[40-49]_Male_grade2      1
# Ages[40-49]_Male_grade3      1
# Ages[15-49]_Female_grade1    0
# Ages[15-49]_Female_grade2    0
# Ages[15-49]_Female_grade3    0
# Ages[20-29]_Female_grade1    0
# Ages[20-29]_Female_grade2    0
# Ages[20-29]_Female_grade3    0
# ...

# %%
if missing_values is not None and missing_values.any():
    # Create a report
    report = pd.DataFrame({
        'Column': missing_values.index,
        'Missing Values': missing_values.values,
        'Percentage Missing': (missing_values / len(df)) * 100
    })

    # Sort the report by the number of missing values in descending order
    report = report.sort_values(by='Missing Values', ascending=False)

    # Print the report
    print(report)
else:
    print("There are no missing values in the DataFrame.")
# Out:
# There are no missing values in the DataFrame.

# %% [markdown]
# # ***SUMMARY
# Based on the ydata-profiling report, the dataset contains information on education attainment across different age groups, genders, and countries. The dataset consists of 38 columns and 626 rows, with no missing values present. The data includes information on the percentage of people in various age groups (15-49) who have completed different levels of education (grade 1 to grade 3), with separate columns for males and females. Additionally, the dataset covers a wide range of countries, including Afghanistan, Angola, and Albania, and spans a period of time from 1981 to 2020.
#
# One of the key findings from the dataset is that the percentage of people who have completed higher levels of education (grade 3) tends to be lower than those who have completed lower levels of education (grade 1 or grade 2). This suggests that there may be barriers or challenges that prevent individuals from pursuing higher levels of education. Furthermore, the dataset reveals differences in education attainment between males and females, as well as between different countries. These differences may be influenced by a range of factors, including cultural and socio-economic factors.
#
# Overall, the dataset provides valuable information on education attainment across different age groups, genders, and countries. The report generated by ydata-profiling helped to identify some interesting patterns and insights in the dataset, which can inform policy decisions and interventions aimed at improving education outcomes.***
